# %% [markdown]
# # Counting Objects in images
# ## By Alejandro Gómez Orjuela and Melanie Giraldo Castaño

# %% [markdown]
# ### 1.Import libraries

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.Charge all localpath
# #### For this proyect,we will used three images,that is why we have three diferents locapath in a vector named images_paths

# %%
image_paths = [
    'data/beatles.jpg',
    'data/cartas.png',
    'data/table.jpg',
    'data/colors.jpg'
]

for i, image_path in enumerate(image_paths):
    image = cv2.imread(image_path)
    if image is None:
        print(f"Warning there is an error with the localpath: {image_path}")
        continue
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(image_rgb)
    plt.title(f'Original image {i+1}')
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### 3.Convert the image to grayscale

# %%
gray_image_paths = []
def convert_to_grayscale(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray_image_path = image_path.replace('.jpg', '_gray.jpg').replace('.jpeg', '_gray.jpeg')
    cv2.imwrite(gray_image_path, gray_image)
    
    gray_image_paths.append(gray_image_path)
    
    plt.figure(figsize=(6, 6))
    plt.imshow(gray_image, cmap='gray')
    plt.title(f'Grayscale - {os.path.basename(gray_image_path)}')
    plt.axis('off')
    plt.show()

for image_path in image_paths:
    convert_to_grayscale(image_path)

# %% [markdown]
# ### 4.Apply a threshold to create a binary image

# %%
binary_image_paths = []
def convert_to_binary_and_store(image_path):
    image = cv2.imread(image_path)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, binary_image = cv2.threshold(gray_image, 128, 255, cv2.THRESH_BINARY)
    binary_image_path = image_path.replace('.jpg', '_binary.jpg').replace('.jpeg', '_binary.jpeg')
    cv2.imwrite(binary_image_path, binary_image)
    binary_image_paths.append(binary_image_path)
    plt.figure(figsize=(6, 6))
    plt.imshow(binary_image, cmap='gray')
    plt.title(f'Binary Image - {os.path.basename(binary_image_path)}')
    plt.axis('off')
    plt.show()

for image_path in gray_image_paths:
    convert_to_binary_and_store(image_path)

# %% [markdown]
# ### 5.Use contour detection to find distinct objects

# %%
contours_list = []
def detect_and_store_contours(binary_image_path):
    binary_image = cv2.imread(binary_image_path, cv2.IMREAD_GRAYSCALE)
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours_list.append(contours)
    plt.figure(figsize=(6, 6))
    plt.imshow(binary_image, cmap='gray')
    plt.title(f'Detected contour - {os.path.basename(binary_image_path)}')
    plt.axis('off')
    plt.show()

    return contours

for binary_image_path in binary_image_paths:
    detect_and_store_contours(binary_image_path)
    
for idx, contours in enumerate(contours_list):
    print(f"Contours detected on the binary image {os.path.basename(binary_image_paths[idx])}: {len(contours)}")
# Out:
# Contours detected on the binary image beatles_gray_binary.jpg: 2776
# Contours detected on the binary image cartas.png: 4
# Contours detected on the binary image table_gray_binary.jpg: 248
# Contours detected on the binary image colors_gray_binary.jpg: 1

# %% [markdown]
# ### 6.Count the number of detected objects and highlight them on the original image

# %%
def count_and_highlight_objects(original_image_path, contours):
    image = cv2.imread(original_image_path)
    num_objects = len(contours)
    cv2.drawContours(image, contours, -1, (0, 255, 0), 2)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6))
    plt.imshow(image_rgb)
    plt.title(f'Image with {num_objects} Detected objects - {os.path.basename(original_image_path)}')
    plt.axis('off')
    plt.show()
    
    return num_objects
for idx, image_path in enumerate(image_paths):
    binary_image_path = image_path.replace('.jpg', '_binary.jpg').replace('.jpeg', '_binary.jpeg')
    contours = contours_list[idx]
    num_objects = count_and_highlight_objects(image_path, contours)
    print(f"Detected objects in {os.path.basename(image_path)}: {num_objects}")
# Out:
# Detected objects in beatles.jpg: 2776
# Detected objects in cartas.png: 4
# Detected objects in table.jpg: 248
# Detected objects in colors.jpg: 1
